# %%
print("My name is Safaeat")
# Out:
# My name is Safaeat

# %%
a=5.00
type(a)
# Out:
# float

# %%
b=10
print(b)
# Out:
# 10

# %%
n=float(input("Enter your bumber1:"))
o=input("Enter your Operator")
m=float(input("Enter your Bumber2:"))
if o=="+":
  print (n+m)
elif o=="-":
  print(n-m)
else:
  print("Enter your number")
# Out:
# Enter your bumber1:34
# Enter your Operator+
# Enter your Bumber2:30
# 64.0
